# %%
s=input("Enter the String:")
print("length:",len(s))
print("Reverse:",s[::-1])
# Out:
# Enter the String:Hermi
# length: 5
# Reverse: imreH

# %%
if s==s[::-1]:
  print("Polindrome")
else:
  print("Not a polindrome")
# Out:
# Not a polindrome

# %%
print("Uppercase:",s.upper())
print("Lowercase:",s.lower())
# Out:
# Uppercase: HERMI
# Lowercase: hermi

# %%
a="Alen savarimuthu"
print("Remove spaces:",a.replace(" ",""))
# Out:
# Remove spaces: Alensavarimuthu

# %%
print("Replace:",s.replace("Hermi","santhru"))
# Out:
# Replace: santhru

# %%
s=input("Enter the string:")
start=int(input("Enter the start index:"))
end=int(input("Enter the end index:"))
substring=s[start:end]
print("Substring:",substring)
# Out:
# Enter the string:Hermina
# Enter the start index:1
# Enter the end index:4
# Substring: erm

# %%
a=input("Enter first string:")
b=input("Enter second string:")
a=a.replace(" ","").lower()
b=b.replace(" ","").lower()
if sorted(a)==sorted(b):
  print("Anagram")
else:
  print("Not Anagram")
# Out:
# Enter first string:Hermi
# Enter second string:Santhru
# Not Anagram

# %%
list=[1,2,3,4,5]
print("first element:",list[0])
print("last element:",list[-1])
# Out:
# first element: 1
# last element: 5

# %%
print(max(list),min(list))
# Out:
# 6 1

# %%
list=[1,2,3,4,5]
list.append(6)
list.remove(3)
print(list)
# Out:
# [1, 2, 4, 5, 6]

# %%
print("reverse:",list[::-1])
# Out:
# reverse: [6, 5, 4, 2, 1]

# %%
print("Ascending:",sorted(list))
print("Descending:",sorted(list,reverse=True))
# Out:
# Ascending: [1, 2, 4, 5, 6]
# Descending: [6, 5, 4, 2, 1]

# %%
list=[1,2,3,4,5,6,6,6]
print("count:",list.count(6))
# Out:
# count: 3

# %%
a=[1,2,3]
b=[3,4,5]
print("merged list:",a+b)
# Out:
# merged list: [1, 2, 3, 3, 4, 5]

# %%
a=[1,2,3,3,4,4,5,5,5,6]
my_unique_list=__builtins__.list(set(a))
print(my_unique_list)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list=[1,2,3,5,6,8]
list.sort()
print("second largest:",list[-2])
# Out:
# second largest: 6

# %%
nums=[1,2,3,4,5,6,7]
even=[]
odd=[]
for num in nums:
  if num%2==0:
    even.append(num)
  else:
    odd.append(num)
print("Even numbers:",even)
print("Odd numbers:",odd)
# Out:
# Even numbers: [2, 4, 6]
# Odd numbers: [1, 3, 5, 7]

# %%
# Create a tuple
tuple1= (10, 20, 30, 40, 50)
print("Tuple elements:", tuple1)
# Out:
# Tuple elements: (10, 20, 30, 40, 50)

# %%
tuple1 = (1, 2, 3, 4)
list = list(tuple1)
list.append(5)
print("Modified list:", list)
# Out:
# Modified list: [1, 2, 3, 4, 5]

# %%
tuple1 = (1, 2, 3, 2, 4, 2, 5)
count = tuple1.count(2)
print("Occurrences:", count)
# Out:
# Occurrences: 3

# %%
tuple1= ("apple", "banana", "orange")
index1 = tuple1.index("banana")
print("Index of banana:", index1)
# Out:
# Index of banana: 1

# %%
tuple1 = (1, 2, 3)
tuple2 = (4, 5, 6)
result = tuple1 + tuple2
print("Concatenated tuple:", result)
# Out:
# Concatenated tuple: (1, 2, 3, 4, 5, 6)

# %%
tuple1= (10, 20, 30, 40, 50, 60)
print("Sliced tuple:", tuple1[1:5])
# Out:
# Sliced tuple: (20, 30, 40, 50)

# %%
tuple1= (100, 200, 300, 400)
if 300 in tuple1:
    print("Element exists")
else:
    print("Element does not exist")
# Out:
# Element exists

# %%
tuple1= ("a", "b", "c", "d", "e")
length = len(tuple1)
print("Length of tuple:", length)
# Out:
# Length of tuple: 5

# %%
my_list = [1, 2, 3, 4]
tuple1 = tuple(my_list)
print("Converted tuple:", tuple1)
# Out:
# Converted tuple: (1, 2, 3, 4)

# %%
tuple1 = ("apple", "orange", "banana")
for item in tuple1:
    print(item)
# Out:
# apple
# orange
# banana

# %%
set1 = {1, 2, 3, 4, 4, 5, 5}
print("Unique elements:", set1)
# Out:
# Unique elements: {1, 2, 3, 4, 5}

# %%
set1 = {10, 20, 30}
set1.add(40)
print("Updated set:", set1)
# Out:
# Updated set: {40, 10, 20, 30}

# %%
set1 = {1, 2, 3, 4, 5}
set1.remove(3)
print("Set after removal:", set1)
# Out:
# Set after removal: {1, 2, 4, 5}

# %%
set1 = {1, 2, 3}
set2 = {3, 4, 5}
result = set1.union(set2)
print("Union of sets:", result)
# Out:
# Union of sets: {1, 2, 3, 4, 5}

# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}
result = set1.intersection(set2)
print("Intersection:", result)
# Out:
# Intersection: {3, 4}

# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5}
result = set1.difference(set2)
print("Difference:", result)
# Out:
# Difference: {1, 2}

# %%
set1 = {100, 200, 300, 400}
if 500 in set1:
    print("Element exists")
else:
    print("Element does not exist")
# Out:
# Element does not exist

# %%
list1 = [1, 2, 2, 3, 4, 4, 5]
list2 = list(set(list1))
print("removing duplicates:", list2)
# Out:
# removing duplicates: [1, 2, 3, 4, 5]

# %%
set = {10, 20, 30, 40}
list1 = list(set)
print("Converted list:", list1)
# Out:
# Converted list: [40, 10, 20, 30]

# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}
result = set1.symmetric_difference(set2)
print("Symmetric Difference:", result)
# Out:
# Symmetric Difference: {1, 2, 5, 6}

# %%
dict= {"name": "hermi","age": 21,"course": "Python"}
print("Keys:", dict.keys())
print("Values:", dict.values())
# Out:
# Keys: dict_keys(['name', 'age', 'course'])
# Values: dict_values(['hermi', 21, 'Python'])

# %%
dict= {"name": "John","age": 21}
dict["course"] = "Python"
print(dict)
# Out:
# {'name': 'John', 'age': 21, 'course': 'Python'}

# %%
dict = {"name": "James","age": 21}
dict["age"] = 22
print(dict)
# Out:
# {'name': 'James', 'age': 22}

# %%
dict= {"name": "santhru","age": 2,"course": "Python"}
del dict["course"]
print(dict)
# Out:
# {'name': 'santhru', 'age': 2}

# %%
dict = {"name": "John","age": 21}
if "age" in dict:
    print("Key exists")
else:
    print("Key does not exist")
# Out:
# Key exists

# %%
dict = {"name": "hermi","age": 21,"course": "Python"}
for key, value in dict.items():
    print(key, ":", value)
# Out:
# name : hermi
# age : 21
# course : Python

# %%
dict1 = {"a": 1,"b": 2}
dict2 = {"c": 3,"d": 4}
result = dict1 | dict2
print(result)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
marks = {"Math": 85,"Science": 92,"English": 78}
max_value = max(marks.values())
print("Maximum value:", max_value)
# Out:
# Maximum value: 92

# %%
numbers = [1, 2, 2, 3, 3, 3, 4]
frequency = {}
for num in numbers:
    if num in frequency:
        frequency[num] += 1
    else:
        frequency[num] = 1
print(frequency)
# Out:
# {1: 1, 2: 2, 3: 3, 4: 1}

# %%
students = {"student1": {"name": "hermi","age": 21},
            "student2": {"name": "santhru", "age": 22 }}
print(students["student1"]["name"])
print(students["student2"]["age"])
# Out:
# hermi
# 22

# %%
import random
words = ["python", "hangman", "programming", "developer", "computer"]
word = random.choice(words)
word_display = ["_"] * len(word)
stages = [
    """
       |
       |
       |
       |
    =========
    """,
    """
       |
       O
       |
       |
    =========
    """,
    """
       |
       O
       |
       |
    =========
    """,
    """
       |
       O
      /
       |
    =========
    """,
    """
       |
       O
      /|
       |
    =========
    """,
    """
       |
       O
      /|\\
       |
    =========
    """,
    """
       |
       O
      /|\\
      / \\
    =========
    """
]
guessed_letters = []
wrong_attempts = 0
max_attempts = 6
print("Welcome to Hangman Game!\n")
while wrong_attempts < max_attempts and "_" in word_display:
    print(stages[wrong_attempts])
    print("Word:", " ".join(word_display))
    print("Guessed Letters:", ", ".join(guessed_letters))
    guess = input("Enter a letter: ").lower()
    if len(guess) != 1 or not guess.isalpha():
        print("Invalid input! Enter a single letter.\n")
        continue
    if guess in guessed_letters:
        print("You already guessed that letter!\n")
        continue
    guessed_letters.append(guess)
    if guess in word:
        print("Correct guess!\n")
        for i in range(len(word)):
            if word[i] == guess:
                word_display[i] = guess
    else:
        wrong_attempts += 1
        print(f"Wrong guess! Attempts left: {max_attempts - wrong_attempts}\n")
print(stages[wrong_attempts])
if "_" not in word_display:
    print("Congratulations! You guessed the word:", word)
else:
    print("Game Over! The word was:", word)
# Out:
# Welcome to Hangman Game!
#
#
#        |
#        |
#        |
#        |
# ...
#
# Word: _ _ _ _ _ _ _
# Guessed Letters:
# Enter a letter: p
# Wrong guess! Attempts left: 5
#
#
#        |
#        O
#        |
#        |
# ...
#
# Word: _ _ _ _ _ _ _
# Guessed Letters: p
# Enter a letter: h
# Correct guess!
#
#
#        |
#        O
#        |
#        |
# ...
#
# Word: h _ _ _ _ _ _
# Guessed Letters: p, h
# Enter a letter: n
# Correct guess!
#
#
#        |
#        O
#        |
#        |
# ...
#
# Word: h _ n _ _ _ n
# Guessed Letters: p, h, n
# Enter a letter: j
# Wrong guess! Attempts left: 4
#
#
#        |
#        O
#        |
#        |
# ...
#
# Word: h _ n _ _ _ n
# Guessed Letters: p, h, n, j
# Enter a letter: t
# Wrong guess! Attempts left: 3
#
#
#        |
#        O
#       /
#        |
# ...
#
# Word: h _ n _ _ _ n
# Guessed Letters: p, h, n, j, t
# Enter a letter: a
# Correct guess!
#
#
#        |
#        O
#       /
#        |
# ...
#
# Word: h a n _ _ a n
# Guessed Letters: p, h, n, j, t, a
# ...
